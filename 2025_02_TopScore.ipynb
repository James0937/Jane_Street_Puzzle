# %% [markdown]
# ![image.png](attachment:image.png)

# %%
list1 = [" ", "admirer", "astir", "black", "dither", "drink", "hoagies", "jolts",
        "okra", "premise", "stickers", "surfaced", "swarm", "wilts", "wrap"]
list2 = [" ", "ark", "children's", "cuirass", "for", "hoe", "isomer", "lane",
        "lords", "nocturnes", "riddle", "sat", "sole", "trionym", "trope"]

# prob 1
target_sentence = f"""
{list1[1]} on the {list1[6]}
{list2[2]} {list2[4]}
{list1[5]} {list1[11]} of the {list2[11]} {list2[12]}
The {list2[10]} {list2[5]} {list2[3]}
{list2[7]} of the {list2[13]} {list2[6]}
... and the {list1[3]} {list2[1]}
{list1[4]} {list1[9]}
{list1[13]} {list1[8]}
{list1[10]} {list2[14]}
{list1[2]} {list1[12]}
{list2[8]} of the {list1[14]}
{list1[7]} of a {list2[9]}
"""

print(target_sentence)
# Out:
# admirer on the hoagies
# children's for
# drink surfaced of the sat sole
# The riddle hoe cuirass
# lane of the trionym isomer
# ... and the black ark
# dither premise
# wilts okra
# stickers trope
# astir swarm
# lords of the wrap
# jolts of a nocturnes

# %%
list1, list2 = list2, list1

another_target_sentence = f"""
{list1[1]} on the {list1[6]}
{list2[2]} {list2[4]}
{list1[5]} {list1[11]} of the {list2[11]} {list2[12]}
The {list2[10]} {list2[5]} {list2[3]}
{list2[7]} of the {list2[13]} {list2[6]}
... and the {list1[3]} {list2[1]}
{list1[4]} {list1[9]}
{list1[13]} {list1[8]}
{list1[10]} {list2[14]}
{list1[2]} {list1[12]}
{list2[8]} of the {list1[14]}
{list1[7]} of a {list2[9]}
"""

print(another_target_sentence)
# Out:
# ark on the isomer
# astir dither
# hoe sat of the surfaced swarm
# The stickers drink black
# jolts of the wilts hoagies
# ... and the cuirass admirer
# for nocturnes
# trionym lords
# riddle wrap
# children's sole
# okra of the trope
# lane of a premise
